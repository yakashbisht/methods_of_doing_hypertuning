# %%
from sklearn.datasets import make_regression
from sklearn.model_selection import train_test_split

# %%
X, y = make_regression(n_samples=1000, n_features=10, noise = 0.1, random_state=1)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)

# %%
X_train.shape, X_test.shape
# Out:
# ((800, 10), (200, 10))

# %%
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR

# %%
lr = LinearRegression()
dtr = DecisionTreeRegressor()
svr = SVR(kernel = "linear")

# %%
#to create ensemble
from sklearn.ensemble import VotingRegressor
ensemble_regressor = VotingRegressor(estimators=[("lr", lr), ("dtr", dtr), ("SVR", svr)])
ensemble_regressor
# Out:
# VotingRegressor(estimators=[('lr', LinearRegression()),
#                             ('dtr', DecisionTreeRegressor()),
#                             ('SVR', SVR(kernel='linear'))])

# %%
ensemble_regressor.fit(X_train, y_train)
# Out:
# VotingRegressor(estimators=[('lr', LinearRegression()),
#                             ('dtr', DecisionTreeRegressor()),
#                             ('SVR', SVR(kernel='linear'))])

# %%
y_pred = ensemble_regressor.predict(X_test) #average of all the prediction will be final prediction
y_pred
# Out:
# array([  51.18729043,   40.84457857, -165.4724235 ,  -38.23499729,
#         503.07435753,  325.50344599,   45.5226995 ,  -46.7398874 ,
#        -106.23432287,  -66.20891468, -101.56014412,   40.71796631,
#         -50.14067936, -143.26542553, -303.61577185, -145.45365535,
#        -280.78341594, -163.33857005,    6.19740743, -187.5724345 ,
#         -44.38230655, -139.13258858,  302.53249562, -204.54359021,
#          81.43984705,  186.52435245,  264.50578396,   58.05584608,
#         -66.79627324,  112.84731007,   71.57114458,  242.09955476,
#         133.77866601,  273.59571139,  121.53350892,  102.45859897,
#          62.79038637, -370.52124758, -184.14777544,  -82.27901067,
#          -6.88778754,  -99.16742966,  108.20962995, -129.89131047,
#          82.36148825,   30.15684664,  178.34780768, -125.05876281,
#         155.26197652, -300.48967015,  224.82575383,  372.39246327,
#        -244.28722286,   77.88087229,  -41.05039087,  167.79305466,
#         184.32945339,   70.6830957 ,   41.42911966,   78.94406464,
#          53.50231918, -422.37454515,  405.95412225,  170.27915411,
#          21.65276553, -192.43140785,  -69.05480307,    1.97952709,
#         -73.8753231 ,  155.62717906,  431.27352691,   52.40909327,
#         -27.9293224 ,  -75.01820412,  155.47217983, -142.92823203,
#         -52.88845444,   33.83657313,   33.57285165,    9.65085909,
#         -94.99963411,  164.67863507,  -74.70557176,   51.06165578,
#        -134.10891564,  183.31855643,   25.79062723, -112.48844982,
#          19.69651588,  -96.76875167, -223.09678849, -216.99899892,
#         -20.62323543,  157.82637301,  135.03218156,   41.86166368,
#         336.09507979, -112.41022345,  107.99483854, -118.50321616,
#        -128.9522666 ,  218.86543155,  117.66536467,  -11.21652277,
#        -269.15438771,  159.57195011,  -13.19844136,  -73.76592016,
#          40.59639487,   59.97080782, -182.84223667,  -79.07824222,
#        -152.87587564,  -29.60041986,  408.92375788,   23.20870697,
#        -155.79184834,   90.21903166, -204.61578138, -185.53048976,
#        -139.54890145,  187.19008655, -123.21045057,  185.4367171 ,
#        -187.32891729,  110.26389893, -405.185333  ,  -87.83432034,
#         206.08233602, -144.99766602,   14.25733168,   84.02423216,
#          84.74001017, -302.34699391,  -34.14966736,   52.68945427,
#         102.74123257, -198.15897418,   88.29617175,  111.4257118 ,
#          92.51864326,  197.98245987,  347.58389839,  254.1878451 ,
#        -103.81816147, -150.78295943,  177.13495992,   56.32574965,
#          71.22461477,  224.14407248,  286.93507587,  177.9201629 ,
#          -0.87335534,  -98.93874057,  -66.09183522,  182.06690797,
#          71.04124069,   69.44792678, -123.0239396 , -343.95638964,
#         356.47667741,  -38.43797022, -424.44778174,  -82.21791223,
#         -71.92127983, -140.26812153,  -29.45360098,  -76.48715324,
#        -192.28068543,  115.12022541, -209.13425844,  -11.56991966,
#         -88.29129673,   21.95974812,  -76.62711626, -115.41136942,
#         -89.53583317,  111.2873945 ,  -33.34044559,  -44.6732423 ,
#          32.09413164,  290.82517927,  145.64643844,   10.00506631,
#          15.10292064, -173.98394469,   29.16125192,  -28.91584622,
#         208.64110296, -161.00682179,  248.22667478,   38.87300985,
#         148.6292996 ,    7.60930181,   51.6387289 ,   68.75672198,
#         106.64515914,  329.49133621, -158.53666585,  -98.29960271])

# %%
from sklearn.metrics import r2_score
r2_score(y_test, y_pred)
# Out:
# 0.951697990843948
